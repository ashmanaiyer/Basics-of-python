# %%
# Creation of Set
thisset = {"cat", "dog", "mouse"}
print(thisset) #it is unordered
# Out:
# {'cat', 'dog', 'mouse'}

# %%
#Duplicates not allowed
thisset = {"cat", "dog", "mouse", "cat"}
print(thisset)
# Out:
# {'cat', 'dog', 'mouse'}

# %%
# the values true and 1 are considerted the same value in sets
thisset = {"cat", "dog", "mouse", True, 1, 2}   #same for 0 and false
print(thisset)
# Out:
# {'cat', True, 'dog', 2, 'mouse'}

# %%
# A set with strings, integers and boolean values:
set1 = {"rahul", 67, True, 41, "male"}
print(set1)
# Out:
# {True, 67, 'rahul', 41, 'male'}

# %%
# To check membership
set = {"rahul", 67, True, 41, "male"}
print("rahul" in set)
print(61 in set)
# Out:
# True
# False

# %%
# You cannot replace the items in a set once its created
# But you can add new items
set = {"rahul", 67, True, 41, "male"}
set.add("mango")
set.remove("rahul")
print(set)
# Out:
# {True, 67, 'mango', 41, 'male'}

# %%
#Set Operations
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}
print(A | B)#Union
print(A & B)#Intersection
print(A - B)#Difference
print(A ^ B)#Symmetric Difference
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}

# %%
participants = ["Alice", "Bob", "Charlie", "Alice", "David", "Bob", "dhvan", "arjit", "john"]

unique_participants = set(participants)
print("Unique Participants:", unique_participants)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-521597969.py in <cell line: 0>()
#       1 participants = ["Alice", "Bob", "Charlie", "Alice", "David", "Bob", "dhvan", "arjit", "john"]
#       2
# ----> 3 unique_participants = set(participants)
#       4 print("Unique Participants:", unique_participants)
#
# TypeError: 'set' object is not callable

# %%
student1 = {"chemistry", "physics", "biology", "maths", "history"}
student2 = {"fine_arts", "physics", "maths", "geology", "english"}
student3 = {"chemistry", "fine_arts", "physics", "maths", "english", "history"}
print("common subjects:", student1 & student2 & student3)
# Out:
# common subjects: {'maths', 'physics'}

# %%
cricket = {"amey", "raj", "raju", "aman", "jai", "dhvan","virat" }
football ={"aditya", "virat", "rohit", "dhvan", "kapil"}
#Intersection
print("Students in both clubs:", cricket & football)
#Symmetric Difference
print("Students in only one club:", cricket ^ football)
# Out:
# Students in both clubs: {'virat', 'dhvan'}
# Students in only one club: {'jai', 'kapil', 'raju', 'aman', 'rohit', 'aditya', 'amey', 'raj'}

# %%
all_students = {"A", "B", "C", "D", "E"}
present_students = {"A", "C", "E"}

absent_students = all_students - present_students

print("All students:", all_students)
print("Present students:", present_students)
print("Absent students:", absent_students)
# Out:
# All students: {'B', 'A', 'C', 'E', 'D'}
# Present students: {'E', 'A', 'C'}
# Absent students: {'D', 'B'}

# %%
valid_courses = {"CS101", "MA201", "PH301", "BI401", "CH501"}
discontinued_course = "PH301"

print("Original valid courses:", valid_courses)

valid_courses.remove(discontinued_course)

print("Valid courses after removing", discontinued_course + ":", valid_courses)

valid_courses.discard("AR101")
print("Valid courses after trying to discard non-existent AR101:", valid_courses)

valid_courses.discard("CS101")
print("Valid courses after discarding CS101:", valid_courses)
# Out:
# Original valid courses: {'MA201', 'BI401', 'CH501', 'CS101', 'PH301'}
# Valid courses after removing PH301: {'MA201', 'BI401', 'CH501', 'CS101'}
# Valid courses after trying to discard non-existent AR101: {'MA201', 'BI401', 'CH501', 'CS101'}
# Valid courses after discarding CS101: {'MA201', 'BI401', 'CH501'}

# %% [markdown]
# **DICTIONARY**

# %%
#Creation of Dictionary
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
#Retriving values from Dictionary
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
#Retriving values from Dictionary
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
# Changing/Adding key: value in dictionary
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
thisdict["colour"] = "red"
x = thisdict.values()
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
# Retrival of values
student ={
    "roll" : '25',
    "name" :"ASHMAN",
    "branch" : "ENTC"
}
print("name:", student["name"])
print("branch:", student["branch"])
# Out:
# name: ASHMAN
# branch: ENTC

# %%
#Adding and updating Elements
student["year"] = "First"
print(student)
student["name"] = "skibidi"
print(student)
# Out:
# {'roll': '25', 'name': 'ASHMAN', 'branch': 'ENTC', 'year': 'First'}
# {'roll': '25', 'name': 'skibidi', 'branch': 'ENTC', 'year': 'First'}

# %%
# Removing Elements
student.pop("year")
print("After removal:", student)
# Out:
# After removal: {'roll': '25', 'name': 'skibidi', 'branch': 'ENTC'}

# %%
thisdict = {
    "apple": 1.50,
    "banana": 0.75,
    "orange": 1.20
}
print("Original dictionary:", thisdict)

# Update the price of a product
product_to_update = "apple"
new_price = 1.75
thisdict[product_to_update] = new_price

print("Updated dictionary:", thisdict)
# Out:
# Original dictionary: {'apple': 1.5, 'banana': 0.75, 'orange': 1.2}
# Updated dictionary: {'apple': 1.75, 'banana': 0.75, 'orange': 1.2}

# %%
student_marks = {
    "A": 85,
    "B": 92,
    "C": 78,
    "D": 95,
    "E": 88
}

search_name = input("Enter the student's name to search for marks: ")

if search_name in student_marks:
    print(f"{search_name}'s marks: {student_marks[search_name]}")
else:
    print(f"Student '{search_name}' not found in the record.")
# Out:
# Enter the student's name to search for marks: B
# B's marks: 92

# %%
student_marks = {
    "A": 85,
    "B": 92,
    "C": 78,
    "D": 95,
    "E": 88
}

search_name = input("Enter the student's name to search for marks: ")
print(student_marks.get(search_name, "Student not found"))
# Out:
# Enter the student's name to search for marks: C
# 78

# %%
usernames_passwords = {
    "user1": "password1",
    "user2": "password2",
    "user3": "password3"
}

username_input = input("Enter your username: ")
password_input = input("Enter your password: ")

stored_password = usernames_passwords.get(username_input)

if stored_password == password_input:
    print("Login successful!")
else:
    print("Invalid username or password.")
# Out:
# Enter your username: user3
# Enter your password: password3
# Login successful!

# %%
marks = {"A": 85, "B": 92, "C": 78, "D": 95, "E": 88}
topper = max(marks, key=marks.get)
print("Topper:", topper)
print("Marks:", marks[topper])
# Out:
# Topper: D
# Marks: 95
