# %% [markdown]
# Name:Ashman V. Aiyer
# PRN:25070123035
# Batch:ENTC- A2

# %%
#Sum and Average of marks of five subjects
a=in89t(input("Enter the marks of the first subject:"))
b=int(input("Enter the marks of the second subject:"))
c=int(input("Enter the marks of the third subject:"))
d=int(input("Enter the marks of the fourth subject:"))
e=int(input("Enter the marks of the fifth subject:"))

sum=a+b+c+d+e
avg=(a+b+c+d+e)/5

print("Total marks:",sum)
print("Average marks:",avg)
# Out:
# Enter the marks of the first subject:70
# Enter the marks of the second subject:0
# Enter the marks of the third subject:0
# Enter the marks of the fourth subject:50
# Enter the marks of the fifth subject:40
# Total marks: 160
# Average marks: 32.0

# %%
#area of a circle
d=int(input("Enter the diameter of the circle:"))
r=d/2
area=3.14*r*r
print("Area:",area)
# Out:
# Enter the diameter of the circle:20
# Area: 314.0

# %%
#area of a rectangle
l=int(input("Enter the length of the rectangle:"))
b=int(input("Enter the breadth of the rectangle:"))
area=l*b
print("Area:",area)
# Out:
# Enter the length of the rectangle:5
# Enter the breadth of the rectangle:10
# Area: 50

# %%
#perimeter of a rectangle
l=int(input("Enter the length of the rectangle:"))
b=int(input("Enter the breadth of the rectangle:"))
peri=2*(l+b)
print("Perimeter:",peri)
# Out:
# Enter the length of the rectangle:2
# Enter the breadth of the rectangle:5
# Perimeter: 14

# %%
#Simple calculator
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
print("1.Addition:",a+b)
print("2.Subtraction:",a-b)
print("3.Multiplication:",a*b)
print("4.Division:",a/b)
# Out:
# Enter the first number:2
# Enter the second number:5
# 1.Addition: 7
# 2.Subtraction: -3
# 3.Multiplication: 10
# 4.Division: 0.4
